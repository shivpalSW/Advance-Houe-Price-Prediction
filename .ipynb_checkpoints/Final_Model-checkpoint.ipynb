# %% [markdown]
# # <center><font color= darkblue> Final Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
import scipy

from sklearn.metrics import r2_score
from sklearn.metrics import SCORERS
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# # DataSet

# %%
df = pd.read_csv('MainDataset')
X = df.drop('SalePrice',axis=1)
y = df['SalePrice']

# %%
X.shape
# Out:
# (2928, 290)

# %% [markdown]
# # Custom Function :
#
# ###### Steps :
# - Train test split and normalization
# - Calculate MAE,RMSE,R2
# - Residual plot and QQ plot

# %%
def ModelTraining(model,X,y,control='No'):
    # Train Test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

    # Scaling to min-max (0-1 range)
    Scaler = MinMaxScaler()
    Scaler.fit(X_train)
    X_train = Scaler.transform(X_train)
    X_test = Scaler.transform(X_test)

    model.fit(X_train,y_train)
    
    if control == 'Yes':
        print(model.best_estimator_)
    else:
        pass
    
    y_pred = model.predict(X_test)
    
    try:
        print('Original value')
        print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
        print('RMSE :',np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred))))
    except:
        print("Log transformed")
        print("MAE : ",mean_absolute_error(y_test,y_pred))
        print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
        return 'overflow encountered in exp print(mean_absolute_error(np.exp(y_test),np.exp(y_pred)))'
    finally:
        print('R2 Score :' , r2_score(y_test,y_pred))
        plt.plot(y_pred,y_test-y_pred,'o')
        plt.xlabel('True')
        plt.ylabel('Residual')
        plt.show() 
        scipy.stats.probplot(y_test-y_pred, dist="norm", plot=plt)

# %% [markdown]
# ## Linear Regression Model

# %%
model = LinearRegression()
ModelTraining(model,X,y,'No')
# Out:
# Original value
# Log transformed
# MAE :  290974305.3431166
# RMSE : 6522582702.574113
# R2 Score : -2.701079083063056e+20
# <ipython-input-3-df473c36836a>:22: RuntimeWarning: overflow encountered in exp
#   print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
# 'overflow encountered in exp print(mean_absolute_error(np.exp(y_test),np.exp(y_pred)))'

# %% [markdown]
# ## Lasso (L1)

# %%
model = Lasso(random_state=101)
param_grid={'alpha': [0.1, 0.09, 0.04, 0.05, 0.07, 0.004]}
gridModel = GridSearchCV(estimator=model,
                         param_grid=param_grid,
                         scoring='neg_mean_absolute_error',
                         cv=5,
                         verbose=1)

ModelTraining(gridModel,X,y,'Yes')
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Lasso(alpha=0.004, random_state=101)
# Original value
# MAE :  20723.739185399554
# RMSE : 35000.30563860575
# R2 Score : 0.8566180914183306

# %% [markdown]
# ## Ridge (L2)

# %%
model = Ridge()
param_grid = {'alpha':[.1,.2,.3,.9,1,5,9,10]}
gridModel = GridSearchCV(estimator=model,
                         param_grid=param_grid,
                        scoring='neg_mean_absolute_error',
                        cv=10,
                        verbose=1)
ModelTraining(gridModel,X,y,'Yes')
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# Ridge(alpha=1)
# Original value
# MAE :  14756.804109604633
# RMSE : 27431.38808003158
# R2 Score : 0.9127040793894553

# %% [markdown]
# ## ElasticNet (L1 + L2)

# %%
model = ElasticNet(tol=0.001)
param_grid = {'alpha':[0.1,0.2,0.3,0.08,0.06,50,100],'l1_ratio':[.1,.3,.5,.9,1]}
gridModel = GridSearchCV(estimator=model,param_grid=param_grid,scoring='neg_mean_absolute_error',
                        cv=10,verbose=0)
ModelTraining(gridModel,X,y,'Yes')
# Out:
# ElasticNet(alpha=0.06, l1_ratio=0.1, tol=0.001)
# Original value
# MAE :  26512.956017808694
# RMSE : 44314.05933652656
# R2 Score : 0.7703789088906651

# %% [markdown]
# ## Support Vector Machine

# %%
model = SVR()
ModelTraining(model,X,y,'no')
# Out:
# Original value
# MAE :  15825.737304556542
# RMSE : 26935.8369809242
# R2 Score : 0.9052187357130085

# %%
varience = []
for comp in range(1,290):
    model = PCA(n_components=comp)
    model.fit(X_train)
    varience.append(np.sum(model.explained_variance_ratio_))
    
plt.plot(range(1,290),varience)

# %%
model = SVR()
param = {'kernel':['rbf'],
    'degree':[3],
    'gamma':['scale','auto'],
    'C':[1.0,5,10,50,100]}

gridModel = GridSearchCV(estimator=model,param_grid=param,scoring='neg_mean_absolute_error',
                        cv=5,verbose=2)

# From above we can take 120 - 150 features instead of 290
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# Scaling to min-max (0-1 range)
Scaler = MinMaxScaler()
Scaler.fit(X_train)
X_train = Scaler.transform(X_train)
X_test = Scaler.transform(X_test)

pca = PCA(n_components=120)
pca.fit(X_train)
pca_X_train = pca.transform(X_train)
pca_X_test  = pca.transform(X_test)

gridModel.fit(pca_X_train,y_train)

y_pred = gridModel.predict(pca_X_test)

try:
    print('Original value')
    print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
    print('RMSE :',np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred))))
except:
    print("Log transformed")
    print("MAE : ",mean_absolute_error(y_test,y_pred))
    print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
finally:
    print('R2 Score :' , r2_score(y_test,y_pred))
    plt.plot(y_pred,y_test-y_pred,'o')
    plt.xlabel('True')
    plt.ylabel('Residual')
    plt.show() 
    scipy.stats.probplot(y_test-y_pred, dist="norm", plot=plt)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ...........C=1.0, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=1.0, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=1.0, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=1.0, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=1.0, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=1.0, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ............C=1.0, degree=3, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=1.0, degree=3, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=1.0, degree=3, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=1.0, degree=3, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .............C=5, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=5, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=5, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=5, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=5, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ..............C=5, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ..............C=5, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ..............C=5, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ..............C=5, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ..............C=5, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ............C=10, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=10, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=10, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=10, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=10, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END .............C=10, degree=3, gamma=auto, kernel=rbf; total time=   0.1s
# [CV] END ............C=50, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=50, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=50, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=50, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=50, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END .............C=50, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .............C=50, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .............C=50, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .............C=50, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .............C=50, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...........C=100, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=100, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=100, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=100, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ...........C=100, degree=3, gamma=scale, kernel=rbf; total time=   0.1s
# [CV] END ............C=100, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ............C=100, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ............C=100, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ............C=100, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ............C=100, degree=3, gamma=auto, kernel=rbf; total time=   0.2s
# Original value
# MAE :  16159.092885061582
# RMSE : 27604.710529230317
# R2 Score : 0.899849908548661

# %% [markdown]
# ## KKNeighborsRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# Scaling to min-max (0-1 range)
Scaler = MinMaxScaler()
Scaler.fit(X_train)
X_train = Scaler.transform(X_train)
X_test = Scaler.transform(X_test)

errors = []
for i in range(1,9):
    model = KNeighborsRegressor(i)
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    error = np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred)))
    errors.append(error)

plt.plot(range(1,9),errors)
# 7 neighbours best

# %%
model = KNeighborsRegressor(n_neighbors=7)
ModelTraining(model,X,y,'no')
# Out:
# Original value
# MAE :  24030.016628658483
# RMSE : 38748.54958828487
# R2 Score : 0.7823925097024562

# %%
model = DecisionTreeRegressor()
ModelTraining(model,X,y,'No')
# Out:
# Original value
# MAE :  25239.265073947667
# RMSE : 39260.94778708139
# R2 Score : 0.7496411585764535

# %% [markdown]
# ## Decision Tree Regressor

# %%
model = DecisionTreeRegressor()
param_grid = { 'max_depth':[10,20,30],
    'min_samples_split':[2,3,4,7,10],
    'min_samples_leaf':[1,2,3,4,5,6,7]}

gridModel = GridSearchCV(model,param_grid=param_grid,scoring='neg_mean_absolute_error',
                        cv=10,verbose=0)
ModelTraining(gridModel,X,y,'Yes')
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=5)
# Original value
# MAE :  23388.038488082173
# RMSE : 35893.466287142444
# R2 Score : 0.7734711929855768

# %% [markdown]
# ## Random Forest Regressor

# %%
model = RandomForestRegressor()
ModelTraining(model,X,y,'No')
# Out:
# Original value
# MAE :  16580.803262815934
# RMSE : 27261.373125521783
# R2 Score : 0.8834068902653265

# %%
model = RandomForestRegressor(random_state=101)
param_grid = { 'n_estimators':[100,120,130,140,150,200]}

gridModel = GridSearchCV(model,param_grid=param_grid,scoring='neg_mean_absolute_error',
                        cv=5,verbose=2)
gridModel.fit(pca_X_train,y_train)

y_pred = gridModel.predict(pca_X_test)

try:
    print('Original value')
    print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
    print('RMSE :',np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred))))
except:
    print("Log transformed")
    print("MAE : ",mean_absolute_error(y_test,y_pred))
    print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
finally:
    print('R2 Score :' , r2_score(y_test,y_pred))
    plt.plot(y_pred,y_test-y_pred,'o')
    plt.xlabel('True')
    plt.ylabel('Residual')
    plt.show() 
    scipy.stats.probplot(y_test-y_pred, dist="norm", plot=plt)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ...................................n_estimators=100; total time=   9.5s
# [CV] END ...................................n_estimators=100; total time=  10.0s
# [CV] END ...................................n_estimators=100; total time=  10.1s
# [CV] END ...................................n_estimators=100; total time=  10.0s
# [CV] END ...................................n_estimators=100; total time=   9.5s
# [CV] END ...................................n_estimators=120; total time=  11.9s
# [CV] END ...................................n_estimators=120; total time=  11.7s
# [CV] END ...................................n_estimators=120; total time=  12.5s
# [CV] END ...................................n_estimators=120; total time=  12.2s
# [CV] END ...................................n_estimators=120; total time=  12.3s
# [CV] END ...................................n_estimators=130; total time=  13.9s
# [CV] END ...................................n_estimators=130; total time=  13.7s
# [CV] END ...................................n_estimators=130; total time=  13.8s
# [CV] END ...................................n_estimators=130; total time=  13.2s
# [CV] END ...................................n_estimators=130; total time=  13.2s
# [CV] END ...................................n_estimators=140; total time=  14.4s
# [CV] END ...................................n_estimators=140; total time=  14.5s
# [CV] END ...................................n_estimators=140; total time=  14.0s
# [CV] END ...................................n_estimators=140; total time=  13.9s
# [CV] END ...................................n_estimators=140; total time=  13.8s
# [CV] END ...................................n_estimators=150; total time=  15.4s
# [CV] END ...................................n_estimators=150; total time=  15.5s
# [CV] END ...................................n_estimators=150; total time=  14.9s
# [CV] END ...................................n_estimators=150; total time=  15.7s
# [CV] END ...................................n_estimators=150; total time=  15.1s
# [CV] END ...................................n_estimators=200; total time=  20.4s
# [CV] END ...................................n_estimators=200; total time=  21.2s
# [CV] END ...................................n_estimators=200; total time=  21.0s
# [CV] END ...................................n_estimators=200; total time=  20.9s
# [CV] END ...................................n_estimators=200; total time=  21.0s
# Original value
# MAE :  23193.491001383114
# RMSE : 38050.73229843552
# R2 Score : 0.803944151423743

# %% [markdown]
# ## Adaboost Regressor

# %%
model = AdaBoostRegressor()
ModelTraining(model,X,y,'No')
# Out:
# Original value
# MAE :  24996.42160830527
# RMSE : 39622.345823873526
# R2 Score : 0.8046637618977778

# %%
model = AdaBoostRegressor()
param_grid = { 'learning_rate':[0.2,0.3],
    'n_estimators':[100,150,180,200]}


gridModel = GridSearchCV(model,param_grid=param_grid,scoring='neg_mean_absolute_error',
                        cv=4,verbose=2)
gridModel.fit(pca_X_train,y_train)

y_pred = gridModel.predict(pca_X_test)
print(gridModel.best_params_)

try:
    print('Original value')
    print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
    print('RMSE :',np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred))))
except:
    print("Log transformed")
    print("MAE : ",mean_absolute_error(y_test,y_pred))
    print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
finally:
    print('R2 Score :' , r2_score(y_test,y_pred))
    plt.plot(y_pred,y_test-y_pred,'o')
    plt.xlabel('True')
    plt.ylabel('Residual')
    plt.show() 
    scipy.stats.probplot(y_test-y_pred, dist="norm", plot=plt)
# Out:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   3.6s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   3.6s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   3.8s
# [CV] END ................learning_rate=0.2, n_estimators=100; total time=   3.8s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time=   5.1s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time=   5.3s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time=   5.1s
# [CV] END ................learning_rate=0.2, n_estimators=150; total time=   4.9s
# [CV] END ................learning_rate=0.2, n_estimators=180; total time=   5.7s
# [CV] END ................learning_rate=0.2, n_estimators=180; total time=   6.0s
# [CV] END ................learning_rate=0.2, n_estimators=180; total time=   5.8s
# [CV] END ................learning_rate=0.2, n_estimators=180; total time=   6.1s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   6.5s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   7.1s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   6.6s
# [CV] END ................learning_rate=0.2, n_estimators=200; total time=   6.6s
# [CV] END ................learning_rate=0.3, n_estimators=100; total time=   3.3s
# [CV] END ................learning_rate=0.3, n_estimators=100; total time=   3.3s
# [CV] END ................learning_rate=0.3, n_estimators=100; total time=   3.9s
# [CV] END ................learning_rate=0.3, n_estimators=100; total time=   3.3s
# [CV] END ................learning_rate=0.3, n_estimators=150; total time=   4.6s
# [CV] END ................learning_rate=0.3, n_estimators=150; total time=   4.7s
# [CV] END ................learning_rate=0.3, n_estimators=150; total time=   5.1s
# [CV] END ................learning_rate=0.3, n_estimators=150; total time=   4.8s
# [CV] END ................learning_rate=0.3, n_estimators=180; total time=   5.7s
# [CV] END ................learning_rate=0.3, n_estimators=180; total time=   6.2s
# [CV] END ................learning_rate=0.3, n_estimators=180; total time=   5.4s
# [CV] END ................learning_rate=0.3, n_estimators=180; total time=   5.9s
# [CV] END ................learning_rate=0.3, n_estimators=200; total time=   5.7s
# [CV] END ................learning_rate=0.3, n_estimators=200; total time=   6.5s
# [CV] END ................learning_rate=0.3, n_estimators=200; total time=   5.8s
# [CV] END ................learning_rate=0.3, n_estimators=200; total time=   6.5s
# {'learning_rate': 0.3, 'n_estimators': 200}
# Original value
# MAE :  29218.11064574805
# RMSE : 45881.792557314446
# R2 Score : 0.7257039630162327

# %% [markdown]
# ## Gradient Boost Regressor

# %%
model = GradientBoostingRegressor()
ModelTraining(model,X,y,'No')
# Out:
# Original value
# MAE :  15621.071836809726
# RMSE : 24374.994525927406
# R2 Score : 0.9013682963533898

# %%
model = GradientBoostingRegressor()
param_grid = { 'learning_rate':[0.1],
    'n_estimators':[400]}

gridModel = GridSearchCV(model,param_grid=param_grid,scoring='neg_mean_absolute_error',
                        cv=5,verbose=2)
gridModel.fit(pca_X_train,y_train)

y_pred = gridModel.predict(pca_X_test)
print(gridModel.best_params_)

try:
    print('Original value')
    print("MAE : ",mean_absolute_error(np.exp(y_test),np.exp(y_pred)))
    print('RMSE :',np.sqrt(mean_squared_error(np.exp(y_test),np.exp(y_pred))))
except:
    print("Log transformed")
    print("MAE : ",mean_absolute_error(y_test,y_pred))
    print('RMSE :',np.sqrt(mean_squared_error(y_test,y_pred)))
finally:
    print('R2 Score :' , r2_score(y_test,y_pred))
    plt.plot(y_pred,y_test-y_pred,'o')
    plt.xlabel('True')
    plt.ylabel('Residual')
    plt.show() 
    scipy.stats.probplot(y_test-y_pred, dist="norm", plot=plt)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END ................learning_rate=0.1, n_estimators=400; total time=  20.6s
# [CV] END ................learning_rate=0.1, n_estimators=400; total time=  20.6s
# [CV] END ................learning_rate=0.1, n_estimators=400; total time=  20.5s
# [CV] END ................learning_rate=0.1, n_estimators=400; total time=  20.6s
# [CV] END ................learning_rate=0.1, n_estimators=400; total time=  21.1s
# {'learning_rate': 0.1, 'n_estimators': 400}
# Original value
# MAE :  21381.89400754854
# RMSE : 34606.66238359067
# R2 Score : 0.8460378135426967

# %% [markdown]
# ## Final Model

# %%
# From Above Training and testing of all the models 
# Ridge, Gradient boost, Support vector regressor,random forest
df = pd.read_csv('MainDataset')
X = df.drop('SalePrice',axis=1)
y = df['SalePrice']

Scaler = MinMaxScaler()

X = Scaler.fit_transform(X)
model = GradientBoostingRegressor()
model.fit(X,y)
# Out:
# GradientBoostingRegressor()

# %%
from joblib import dump
dump(model,'Advance_house_price.pkl')
# Out:
# ['Advance_house_price.pkl']
